# %%
import pandas as pd
data=pd.read_csv("circles_binary_classification.csv")

# %%
data.describe()
# Out:
#                 X1           X2       label
# count  1000.000000  1000.000000  1000.00000
# mean     -0.000448    -0.000804     0.50000
# std       0.639837     0.641156     0.50025
# min      -1.059502    -1.067768     0.00000
# 25%      -0.619251    -0.612176     0.00000
# 50%       0.008762    -0.003949     0.50000
# 75%       0.621933     0.624822     1.00000
# max       1.033712     1.036004     1.00000

# %%
data.head()
# Out:
#          X1        X2  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      1000 non-null   float64
#  1   X2      1000 non-null   float64
#  2   label   1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %% [markdown]
# Data cleaning
#
# Here all the data are not null so , it requires no data preparation is not required

# %% [markdown]
# **#General Data Visualization**
#
# Plotting the data cause its plottable.
#
# x1,x2 and label(0,1)

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data.X1,y=data.X2,c=data.label)

# %%
X=data[['X1','X2']].values
Y=data['label'].values
print(X.shape,Y.shape)
# Out:
# (1000, 2) (1000,)

# %%
import torch
X=torch.from_numpy(X).type(torch.float)
Y=torch.from_numpy(Y).type(torch.float)
# looking at the object 
X[:5],Y[:5]
# Out:
# (tensor([[ 0.7542,  0.2315],
#          [-0.7562,  0.1533],
#          [-0.8154,  0.1733],
#          [-0.3937,  0.6929],
#          [ 0.4422, -0.8967]]),
#  tensor([1., 1., 1., 1., 0.]))

# %%
# Split data into train and test sets
# sklearn.model_selection
# train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    Y,
                                                    test_size=0.2, # 20% test, 80% train
                                                    random_state=42) # make the random split reproducible

print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 800 200 800 200

# %%
from torch import nn

device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
# Out:
# cpu

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()

        self.layer1 = nn.Linear(in_features=2, out_features=11)
        self.layer2 = nn.Linear(in_features=11, out_features=11)
        self.layer3 = nn.Linear(in_features=11, out_features=11)
        self.layer4 = nn.Linear(in_features=11, out_features=1)
        self.relu = nn.ReLU() # Adding Activation function

    def forward(self, x):
        return self.layer4(self.relu(self.layer3(self.relu(self.layer2(self.relu(self.layer1(x)))))))

ClassificationModel = Model().to(device)

print(ClassificationModel)
# Out:
# Model(
#   (layer1): Linear(in_features=2, out_features=11, bias=True)
#   (layer2): Linear(in_features=11, out_features=11, bias=True)
#   (layer3): Linear(in_features=11, out_features=11, bias=True)
#   (layer4): Linear(in_features=11, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
untrained_pred = ClassificationModel(X_test.to(device))

print(f"Length of predictions: {len(untrained_pred)}, Shape: {untrained_pred.shape}")
print(f"Length of test samples: {len(y_test)}, Shape: {y_test.shape}")
print(f"\nFirst 10 predictions:\n{untrained_pred[:10]}")
print(f"\nFirst 10 test labels:\n{y_test[:10]}")
# Out:
# Length of predictions: 200, Shape: torch.Size([200, 1])
# Length of test samples: 200, Shape: torch.Size([200])
#
# First 10 predictions:
# tensor([[-0.1445],
#         [-0.1389],
#         [-0.1454],
#         [-0.1476],
#         [-0.1300],
#         [-0.1293],
#         [-0.1254],
#         [-0.1270],
#         [-0.1455],
#         [-0.1381]], grad_fn=<SliceBackward0>)
#
# First 10 test labels:
# tensor([1., 0., 1., 0., 1., 1., 0., 0., 1., 0.])

# %%
#first 5 prediction
y_pred_labels = torch.round(torch.sigmoid(ClassificationModel(X_test.to(device))[:5]))

print(y_pred_labels)
# Out:
# tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], grad_fn=<RoundBackward0>)

# %%
# Create a loss function
# loss_fn = nn.BCELoss() # BCELoss = no sigmoid built-in
loss_fn = nn.BCEWithLogitsLoss() # BCEWithLogitsLoss = sigmoid built-in

# Create an optimizer
optimizer = torch.optim.SGD(params=ClassificationModel.parameters(),
                            lr=0.2)

# Calculate accuracy (a classification metric)
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item() # torch.eq() calculates where two tensors are equal
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
torch.manual_seed(42)

# Set the number of epochs
epochs = 1280

# Put data to target device
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

def train_and_test_loop(
    model: nn.Module,
    epochs: int,
    X_train: torch.Tensor,
    y_train: torch.Tensor,
    X_test: torch.Tensor,
    y_test: torch.Tensor,
    loss_fn: nn.Module,
    optimizer: torch.optim.Optimizer
):
    # lists
    loss_list = []
    acc_list = []
    test_losses = []
    test_acc_list = []



    # Build training and evaluation loop
    for epoch in range(epochs):
        ### Training
        model.train()

        # 1. Forward pass (model outputs raw logits)
        y_logits = model(X_train).squeeze() # squeeze to remove extra `1` dimensions, this won't work unless model and data are on same device
        y_pred = torch.round(torch.sigmoid(y_logits)) # turn logits -> pred probs -> pred labls

        # 2. Calculate loss/accuracy
        # loss = loss_fn(torch.sigmoid(y_logits), # Using nn.BCELoss you need torch.sigmoid()
        #                y_train)
        loss = loss_fn(y_logits, # Using nn.BCEWithLogitsLoss works with raw logits
                    y_train)
        acc = accuracy_fn(y_true=y_train,
                        y_pred=y_pred)

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backwards
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        ### Testing
        model.eval()
        with torch.inference_mode():
            # 1. Forward pass
            test_logits = model(X_test).squeeze()
            test_pred = torch.round(torch.sigmoid(test_logits))
            # 2. Caculate loss/accuracy
            test_loss = loss_fn(test_logits,
                                y_test)
            test_acc = accuracy_fn(y_true=y_test,
                                y_pred=test_pred)


        loss_list.append(loss.item())
        acc_list.append(acc)
        test_losses.append(test_loss.item())
        test_acc_list.append(test_acc)

        # Print out what's happening every 10 epochs
        if epoch % 10 == 0:
            print(f"Epoch: {epoch} | Loss: {loss:.5f}, Accuracy: {acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%")

    return loss_list, acc_list, test_losses, test_acc_list

# %%
train_losses, acc_list, test_losses, test_acc = train_and_test_loop(
    model=ClassificationModel,
    epochs=epochs,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    loss_fn=loss_fn,
    optimizer=optimizer
)
# Out:
# Epoch: 0 | Loss: 0.69530, Accuracy: 50.00% | Test loss: 0.69504, Test acc: 50.00%
# Epoch: 10 | Loss: 0.69355, Accuracy: 50.00% | Test loss: 0.69352, Test acc: 50.00%
# Epoch: 20 | Loss: 0.69302, Accuracy: 50.00% | Test loss: 0.69306, Test acc: 50.00%
# Epoch: 30 | Loss: 0.69285, Accuracy: 50.00% | Test loss: 0.69291, Test acc: 50.00%
# Epoch: 40 | Loss: 0.69278, Accuracy: 51.62% | Test loss: 0.69284, Test acc: 49.00%
# Epoch: 50 | Loss: 0.69273, Accuracy: 49.50% | Test loss: 0.69279, Test acc: 51.00%
# Epoch: 60 | Loss: 0.69269, Accuracy: 52.12% | Test loss: 0.69275, Test acc: 52.50%
# Epoch: 70 | Loss: 0.69265, Accuracy: 55.12% | Test loss: 0.69271, Test acc: 55.00%
# Epoch: 80 | Loss: 0.69261, Accuracy: 55.38% | Test loss: 0.69267, Test acc: 55.50%
# Epoch: 90 | Loss: 0.69257, Accuracy: 55.38% | Test loss: 0.69262, Test acc: 55.50%
# Epoch: 100 | Loss: 0.69253, Accuracy: 55.62% | Test loss: 0.69258, Test acc: 55.50%
# Epoch: 110 | Loss: 0.69249, Accuracy: 56.12% | Test loss: 0.69254, Test acc: 56.50%
# Epoch: 120 | Loss: 0.69245, Accuracy: 57.38% | Test loss: 0.69250, Test acc: 56.50%
# Epoch: 130 | Loss: 0.69240, Accuracy: 57.63% | Test loss: 0.69245, Test acc: 57.00%
# Epoch: 140 | Loss: 0.69235, Accuracy: 57.50% | Test loss: 0.69240, Test acc: 59.00%
# Epoch: 150 | Loss: 0.69230, Accuracy: 57.12% | Test loss: 0.69235, Test acc: 58.50%
# Epoch: 160 | Loss: 0.69225, Accuracy: 57.00% | Test loss: 0.69230, Test acc: 58.00%
# Epoch: 170 | Loss: 0.69219, Accuracy: 55.75% | Test loss: 0.69224, Test acc: 58.00%
# Epoch: 180 | Loss: 0.69213, Accuracy: 55.50% | Test loss: 0.69218, Test acc: 57.00%
# Epoch: 190 | Loss: 0.69207, Accuracy: 55.88% | Test loss: 0.69211, Test acc: 56.50%
# Epoch: 200 | Loss: 0.69199, Accuracy: 56.12% | Test loss: 0.69204, Test acc: 56.00%
# Epoch: 210 | Loss: 0.69191, Accuracy: 55.62% | Test loss: 0.69196, Test acc: 56.50%
# Epoch: 220 | Loss: 0.69182, Accuracy: 55.75% | Test loss: 0.69187, Test acc: 55.00%
# Epoch: 230 | Loss: 0.69171, Accuracy: 56.38% | Test loss: 0.69176, Test acc: 54.00%
# Epoch: 240 | Loss: 0.69158, Accuracy: 57.12% | Test loss: 0.69165, Test acc: 55.00%
# Epoch: 250 | Loss: 0.69144, Accuracy: 57.75% | Test loss: 0.69153, Test acc: 56.50%
# Epoch: 260 | Loss: 0.69124, Accuracy: 59.13% | Test loss: 0.69137, Test acc: 56.50%
# Epoch: 270 | Loss: 0.69109, Accuracy: 59.75% | Test loss: 0.69124, Test acc: 57.00%
# Epoch: 280 | Loss: 0.69094, Accuracy: 59.75% | Test loss: 0.69110, Test acc: 57.50%
# Epoch: 290 | Loss: 0.69079, Accuracy: 59.50% | Test loss: 0.69095, Test acc: 58.00%
# Epoch: 300 | Loss: 0.69062, Accuracy: 60.00% | Test loss: 0.69079, Test acc: 59.50%
# Epoch: 310 | Loss: 0.69044, Accuracy: 60.25% | Test loss: 0.69062, Test acc: 60.00%
# Epoch: 320 | Loss: 0.69024, Accuracy: 61.25% | Test loss: 0.69043, Test acc: 61.50%
# Epoch: 330 | Loss: 0.69000, Accuracy: 62.00% | Test loss: 0.69020, Test acc: 61.00%
# Epoch: 340 | Loss: 0.68976, Accuracy: 62.12% | Test loss: 0.68996, Test acc: 62.00%
# Epoch: 350 | Loss: 0.68950, Accuracy: 62.62% | Test loss: 0.68969, Test acc: 62.00%
# Epoch: 360 | Loss: 0.68921, Accuracy: 63.12% | Test loss: 0.68940, Test acc: 63.50%
# Epoch: 370 | Loss: 0.68889, Accuracy: 64.25% | Test loss: 0.68908, Test acc: 64.00%
# Epoch: 380 | Loss: 0.68854, Accuracy: 65.88% | Test loss: 0.68873, Test acc: 64.50%
# Epoch: 390 | Loss: 0.68815, Accuracy: 66.75% | Test loss: 0.68833, Test acc: 66.50%
# Epoch: 400 | Loss: 0.68772, Accuracy: 69.00% | Test loss: 0.68789, Test acc: 69.00%
# Epoch: 410 | Loss: 0.68723, Accuracy: 70.12% | Test loss: 0.68738, Test acc: 71.00%
# Epoch: 420 | Loss: 0.68667, Accuracy: 71.62% | Test loss: 0.68681, Test acc: 71.00%
# Epoch: 430 | Loss: 0.68603, Accuracy: 72.12% | Test loss: 0.68615, Test acc: 71.00%
# Epoch: 440 | Loss: 0.68530, Accuracy: 73.50% | Test loss: 0.68539, Test acc: 71.50%
# Epoch: 450 | Loss: 0.68446, Accuracy: 75.75% | Test loss: 0.68451, Test acc: 74.00%
# Epoch: 460 | Loss: 0.68349, Accuracy: 77.00% | Test loss: 0.68350, Test acc: 73.50%
# Epoch: 470 | Loss: 0.68227, Accuracy: 78.75% | Test loss: 0.68228, Test acc: 74.50%
# Epoch: 480 | Loss: 0.68089, Accuracy: 80.38% | Test loss: 0.68092, Test acc: 75.50%
# Epoch: 490 | Loss: 0.67937, Accuracy: 81.38% | Test loss: 0.67938, Test acc: 76.00%
# Epoch: 500 | Loss: 0.67763, Accuracy: 82.12% | Test loss: 0.67759, Test acc: 81.00%
# Epoch: 510 | Loss: 0.67559, Accuracy: 84.88% | Test loss: 0.67550, Test acc: 82.50%
# Epoch: 520 | Loss: 0.67321, Accuracy: 86.50% | Test loss: 0.67309, Test acc: 84.50%
# Epoch: 530 | Loss: 0.67036, Accuracy: 88.38% | Test loss: 0.67028, Test acc: 87.50%
# Epoch: 540 | Loss: 0.66694, Accuracy: 89.12% | Test loss: 0.66696, Test acc: 88.00%
# Epoch: 550 | Loss: 0.66276, Accuracy: 89.50% | Test loss: 0.66296, Test acc: 88.00%
# Epoch: 560 | Loss: 0.65765, Accuracy: 89.50% | Test loss: 0.65805, Test acc: 88.50%
# Epoch: 570 | Loss: 0.65132, Accuracy: 89.88% | Test loss: 0.65210, Test acc: 88.50%
# Epoch: 580 | Loss: 0.64341, Accuracy: 90.25% | Test loss: 0.64476, Test acc: 91.00%
# Epoch: 590 | Loss: 0.63352, Accuracy: 90.25% | Test loss: 0.63562, Test acc: 91.00%
# Epoch: 600 | Loss: 0.62096, Accuracy: 90.62% | Test loss: 0.62423, Test acc: 89.50%
# Epoch: 610 | Loss: 0.60489, Accuracy: 90.75% | Test loss: 0.60959, Test acc: 89.00%
# Epoch: 620 | Loss: 0.58883, Accuracy: 91.88% | Test loss: 0.61187, Test acc: 57.50%
# Epoch: 630 | Loss: 0.57975, Accuracy: 85.75% | Test loss: 0.61618, Test acc: 52.50%
# Epoch: 640 | Loss: 0.58546, Accuracy: 64.25% | Test loss: 0.65266, Test acc: 50.00%
# Epoch: 650 | Loss: 0.56608, Accuracy: 67.00% | Test loss: 0.61995, Test acc: 52.00%
# Epoch: 660 | Loss: 0.57101, Accuracy: 57.12% | Test loss: 0.61376, Test acc: 52.00%
# Epoch: 670 | Loss: 0.60779, Accuracy: 50.88% | Test loss: 0.67214, Test acc: 50.00%
# Epoch: 680 | Loss: 0.54178, Accuracy: 62.25% | Test loss: 0.59480, Test acc: 52.00%
# Epoch: 690 | Loss: 0.55044, Accuracy: 56.38% | Test loss: 0.57848, Test acc: 54.50%
# Epoch: 700 | Loss: 0.61534, Accuracy: 50.38% | Test loss: 0.65216, Test acc: 50.00%
# Epoch: 710 | Loss: 0.54795, Accuracy: 55.50% | Test loss: 0.62322, Test acc: 50.50%
# Epoch: 720 | Loss: 0.52255, Accuracy: 59.50% | Test loss: 0.55574, Test acc: 56.00%
# Epoch: 730 | Loss: 0.56133, Accuracy: 52.50% | Test loss: 0.58663, Test acc: 52.00%
# Epoch: 740 | Loss: 0.57348, Accuracy: 51.75% | Test loss: 0.60861, Test acc: 50.50%
# Epoch: 750 | Loss: 0.54101, Accuracy: 54.75% | Test loss: 0.58238, Test acc: 52.50%
# Epoch: 760 | Loss: 0.54026, Accuracy: 54.75% | Test loss: 0.57199, Test acc: 53.50%
# Epoch: 770 | Loss: 0.54109, Accuracy: 54.75% | Test loss: 0.56876, Test acc: 54.50%
# Epoch: 780 | Loss: 0.53670, Accuracy: 56.00% | Test loss: 0.56262, Test acc: 56.00%
# Epoch: 790 | Loss: 0.53410, Accuracy: 56.38% | Test loss: 0.55601, Test acc: 57.50%
# Epoch: 800 | Loss: 0.52839, Accuracy: 57.63% | Test loss: 0.54857, Test acc: 57.50%
# Epoch: 810 | Loss: 0.52490, Accuracy: 58.88% | Test loss: 0.54081, Test acc: 61.00%
# Epoch: 820 | Loss: 0.52037, Accuracy: 59.62% | Test loss: 0.53464, Test acc: 61.50%
# Epoch: 830 | Loss: 0.51482, Accuracy: 60.25% | Test loss: 0.52701, Test acc: 62.50%
# Epoch: 840 | Loss: 0.51054, Accuracy: 61.00% | Test loss: 0.51866, Test acc: 64.00%
# Epoch: 850 | Loss: 0.50737, Accuracy: 61.75% | Test loss: 0.51426, Test acc: 65.00%
# Epoch: 860 | Loss: 0.50251, Accuracy: 62.88% | Test loss: 0.50821, Test acc: 65.50%
# Epoch: 870 | Loss: 0.49572, Accuracy: 63.75% | Test loss: 0.49951, Test acc: 66.50%
# Epoch: 880 | Loss: 0.49155, Accuracy: 64.50% | Test loss: 0.49401, Test acc: 66.50%
# Epoch: 890 | Loss: 0.49017, Accuracy: 64.75% | Test loss: 0.48969, Test acc: 66.50%
# Epoch: 900 | Loss: 0.48421, Accuracy: 65.62% | Test loss: 0.48527, Test acc: 67.00%
# Epoch: 910 | Loss: 0.47450, Accuracy: 67.00% | Test loss: 0.47370, Test acc: 68.00%
# Epoch: 920 | Loss: 0.47203, Accuracy: 67.00% | Test loss: 0.47244, Test acc: 69.00%
# Epoch: 930 | Loss: 0.46849, Accuracy: 67.62% | Test loss: 0.46914, Test acc: 69.00%
# Epoch: 940 | Loss: 0.46050, Accuracy: 68.62% | Test loss: 0.46777, Test acc: 70.00%
# Epoch: 950 | Loss: 0.44580, Accuracy: 70.38% | Test loss: 0.45320, Test acc: 70.50%
# Epoch: 960 | Loss: 0.45021, Accuracy: 69.88% | Test loss: 0.45418, Test acc: 71.00%
# Epoch: 970 | Loss: 0.43788, Accuracy: 70.75% | Test loss: 0.45223, Test acc: 71.00%
# Epoch: 980 | Loss: 0.41771, Accuracy: 73.38% | Test loss: 0.42228, Test acc: 73.00%
# Epoch: 990 | Loss: 0.46099, Accuracy: 69.00% | Test loss: 0.48188, Test acc: 69.50%
# Epoch: 1000 | Loss: 0.34386, Accuracy: 81.88% | Test loss: 0.36376, Test acc: 80.00%
# Epoch: 1010 | Loss: 0.56940, Accuracy: 62.12% | Test loss: 0.51261, Test acc: 66.50%
# Epoch: 1020 | Loss: 0.21016, Accuracy: 95.50% | Test loss: 0.24319, Test acc: 89.50%
# Epoch: 1030 | Loss: 0.58554, Accuracy: 61.38% | Test loss: 0.47250, Test acc: 71.50%
# Epoch: 1040 | Loss: 0.15773, Accuracy: 98.12% | Test loss: 0.18598, Test acc: 93.50%
# Epoch: 1050 | Loss: 0.91895, Accuracy: 54.37% | Test loss: 1.06630, Test acc: 51.50%
# Epoch: 1060 | Loss: 0.11878, Accuracy: 99.75% | Test loss: 0.14232, Test acc: 100.00%
# Epoch: 1070 | Loss: 0.08972, Accuracy: 99.88% | Test loss: 0.11577, Test acc: 99.50%
# Epoch: 1080 | Loss: 0.07330, Accuracy: 99.88% | Test loss: 0.10068, Test acc: 99.00%
# Epoch: 1090 | Loss: 0.13933, Accuracy: 95.50% | Test loss: 0.31828, Test acc: 82.00%
# Epoch: 1100 | Loss: 0.14546, Accuracy: 98.50% | Test loss: 0.15954, Test acc: 97.00%
# Epoch: 1110 | Loss: 0.09143, Accuracy: 99.75% | Test loss: 0.11441, Test acc: 98.50%
# Epoch: 1120 | Loss: 0.08651, Accuracy: 99.00% | Test loss: 0.11787, Test acc: 97.00%
# Epoch: 1130 | Loss: 1.10133, Accuracy: 52.12% | Test loss: 0.47948, Test acc: 75.50%
# Epoch: 1140 | Loss: 0.07459, Accuracy: 100.00% | Test loss: 0.09415, Test acc: 100.00%
# Epoch: 1150 | Loss: 0.05685, Accuracy: 100.00% | Test loss: 0.07767, Test acc: 100.00%
# Epoch: 1160 | Loss: 0.04675, Accuracy: 100.00% | Test loss: 0.06787, Test acc: 100.00%
# Epoch: 1170 | Loss: 0.03986, Accuracy: 100.00% | Test loss: 0.06077, Test acc: 100.00%
# Epoch: 1180 | Loss: 0.03482, Accuracy: 100.00% | Test loss: 0.05545, Test acc: 100.00%
# Epoch: 1190 | Loss: 0.03090, Accuracy: 99.88% | Test loss: 0.05122, Test acc: 100.00%
# Epoch: 1200 | Loss: 0.02779, Accuracy: 99.88% | Test loss: 0.04782, Test acc: 100.00%
# Epoch: 1210 | Loss: 0.02527, Accuracy: 99.88% | Test loss: 0.04498, Test acc: 100.00%
# Epoch: 1220 | Loss: 0.02319, Accuracy: 99.88% | Test loss: 0.04254, Test acc: 100.00%
# Epoch: 1230 | Loss: 0.02143, Accuracy: 99.88% | Test loss: 0.04043, Test acc: 100.00%
# Epoch: 1240 | Loss: 0.01993, Accuracy: 99.88% | Test loss: 0.03858, Test acc: 100.00%
# Epoch: 1250 | Loss: 0.01863, Accuracy: 99.88% | Test loss: 0.03695, Test acc: 100.00%
# Epoch: 1260 | Loss: 0.01750, Accuracy: 99.88% | Test loss: 0.03550, Test acc: 100.00%
# Epoch: 1270 | Loss: 0.01650, Accuracy: 99.88% | Test loss: 0.03419, Test acc: 100.00%

# %% [markdown]
# Helper function
#
# Taken from the povided resources.

# %%
import numpy as np

def plot_decision_boundary(model: torch.nn.Module, X: torch.Tensor, y: torch.Tensor):
    """Plots decision boundaries of model predicting on X in comparison to y.

    Source - https://madewithml.com/courses/foundations/neural-networks/ (with modifications)
    """
    # Put everything to CPU (works better with NumPy + Matplotlib)
    model.to("cpu")
    X, y = X.to("cpu"), y.to("cpu")

    # Setup prediction boundaries and grid
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 101), np.linspace(y_min, y_max, 101))

    # Make features
    X_to_pred_on = torch.from_numpy(np.column_stack((xx.ravel(), yy.ravel()))).float()

    # Make predictions
    model.eval()
    with torch.inference_mode():
        y_logits = model(X_to_pred_on)

    # Test for multi-class or binary and adjust logits to prediction labels
    if len(torch.unique(y)) > 2:
        y_pred = torch.softmax(y_logits, dim=1).argmax(dim=1)  # mutli-class
    else:
        y_pred = torch.round(torch.sigmoid(y_logits))  # binary

    # Reshape preds and plot
    y_pred = y_pred.reshape(xx.shape).detach().numpy()
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
# Plot decision boundaries for training and test sets
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(ClassificationModel, X_train, y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(ClassificationModel, X_test, y_test)
